# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls
# Out:
# 'Evaluation Metric example.xlsx'   sample_submission.csv   train.csv
# 'Problem Statement.docx'           test.csv

# %%
 cd drive/My\ Drive/New\ Problem\ Statement\ for\ GC\ Data\ Analytics
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/New Problem Statement for GC Data Analytics'
# /content/drive/My Drive/New Problem Statement for GC Data Analytics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train=pd.read_csv("train.csv", header=0, index_col=0)
train.head()
# Out:
#                       main_meter  sub_meter_1  sub_meter_2  building_number
# timestamp
# 2017-04-01 00:00:00  2898.969633  1390.244624     0.000000                1
# 2017-04-01 00:15:00  2531.896894  1087.313897     0.000000                1
# 2017-04-01 00:30:00  2171.649138   695.625737     0.484790                1
# 2017-04-01 00:45:00  2207.299159   615.496571     1.317875                1
# 2017-04-01 01:00:00  2839.441067  1071.573744     0.000000                1

# %%
# train['Datetime'] = pd.to_datetime(train.timestamp,format='%Y-%m-%d %H:%M:%S') 
# train.drop(['Datetime'], axis = 1, inplace = True)
# train.head()

# %%
train.describe()
# Out:
#           main_meter    sub_meter_1    sub_meter_2  building_number
# count  132000.000000  132000.000000  132000.000000    132000.000000
# mean     6095.767107    2092.888851     776.830989         3.000000
# std      3485.125319    1135.885749     883.495350         1.414219
# min        61.635635       0.000000       0.000000         1.000000
# 25%      3455.911410    1365.005373       4.857540         2.000000
# 50%      5362.188090    2075.676367     621.910511         3.000000
# 75%      7685.405459    2772.505817    1365.898059         4.000000
# max     23174.609258   17206.162311    4392.073840         5.000000

# %%
import seaborn as sns
sns.heatmap(train.corr())

# %%
train.corr()
# Out:
#                  main_meter  sub_meter_1  sub_meter_2  building_number
# main_meter         1.000000     0.519466     0.571422         0.181057
# sub_meter_1        0.519466     1.000000     0.064828         0.042826
# sub_meter_2        0.571422     0.064828     1.000000         0.436140
# building_number    0.181057     0.042826     0.436140         1.000000

# %%
bui_1=train.loc[train['building_number']==1]
bui_2=train.loc[train['building_number']==2]
bui_3=train.loc[train['building_number']==3]
bui_4=train.loc[train['building_number']==4]
bui_5=train.loc[train['building_number']==5]

# %%
bui_1
# Out:
#                       main_meter  sub_meter_1  sub_meter_2  building_number
# timestamp
# 2017-04-01 00:00:00  2898.969633  1390.244624     0.000000                1
# 2017-04-01 00:15:00  2531.896894  1087.313897     0.000000                1
# 2017-04-01 00:30:00  2171.649138   695.625737     0.484790                1
# 2017-04-01 00:45:00  2207.299159   615.496571     1.317875                1
# 2017-04-01 01:00:00  2839.441067  1071.573744     0.000000                1
# ...                          ...          ...          ...              ...
# 2017-12-31 22:45:00  1940.269619   838.899936     4.973363                1
# 2017-12-31 23:00:00  2032.948747   871.474029     0.000000                1
# 2017-12-31 23:15:00  2090.305746   894.499291     1.807203                1
# 2017-12-31 23:30:00  2007.119194   827.307818     0.000000                1
# 2017-12-31 23:45:00  2163.604520   854.982388     4.797980                1
#
# [26400 rows x 4 columns]

# %%
bui_1.corr()
# Out:
#                  main_meter  sub_meter_1  sub_meter_2  building_number
# main_meter         1.000000     0.560315     0.789609              NaN
# sub_meter_1        0.560315     1.000000     0.448726              NaN
# sub_meter_2        0.789609     0.448726     1.000000              NaN
# building_number         NaN          NaN          NaN              NaN

# %%
bui_2.corr()
# Out:
#                  main_meter  sub_meter_1  sub_meter_2  building_number
# main_meter         1.000000     0.748774     0.586738              NaN
# sub_meter_1        0.748774     1.000000     0.487656              NaN
# sub_meter_2        0.586738     0.487656     1.000000              NaN
# building_number         NaN          NaN          NaN              NaN

# %%
bui_3.corr()
# Out:
#                  main_meter  sub_meter_1  sub_meter_2  building_number
# main_meter         1.000000     0.795733     0.685379              NaN
# sub_meter_1        0.795733     1.000000     0.605374              NaN
# sub_meter_2        0.685379     0.605374     1.000000              NaN
# building_number         NaN          NaN          NaN              NaN

# %%
bui_4.corr()
# Out:
#                  main_meter  sub_meter_1  sub_meter_2  building_number
# main_meter         1.000000     0.707989     0.769140              NaN
# sub_meter_1        0.707989     1.000000     0.649064              NaN
# sub_meter_2        0.769140     0.649064     1.000000              NaN
# building_number         NaN          NaN          NaN              NaN

# %%
bui_5.corr()
# Out:
#                  main_meter  sub_meter_1  sub_meter_2  building_number
# main_meter         1.000000     0.828567     0.738915              NaN
# sub_meter_1        0.828567     1.000000     0.745663              NaN
# sub_meter_2        0.738915     0.745663     1.000000              NaN
# building_number         NaN          NaN          NaN              NaN

# %%
bui_5.describe()
# Out:
#          main_meter   sub_meter_1   sub_meter_2  building_number
# count  26400.000000  26400.000000  26400.000000          26400.0
# mean    6200.094589   2479.201572    725.197170              5.0
# std     3851.811665    919.215814    650.336132              0.0
# min     1662.094739    567.387049      0.000000              5.0
# 25%     2964.966639   1675.681930      1.086344              5.0
# 50%     5364.191349   2408.675611   1308.287194              5.0
# 75%     8773.463678   3231.339714   1320.751681              5.0
# max    20521.022678   5250.604095   1396.889334              5.0

# %%
from matplotlib import pyplot

dataset = pd.read_csv('train.csv', header=0, index_col=0)
values = dataset.values
# specify columns to plot
groups = [0, 1, 2,3]
i = 1
# plot each column
pyplot.figure(figsize=(20,10))

for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(dataset.columns[group], y=0.5, loc='right')
	i += 1
pyplot.show()

# %%
values = bui_1.values
# specify columns to plot
groups = [0, 1, 2,3]
i = 1
# plot each column
pyplot.figure(figsize=(20,10))

for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(dataset.columns[group], y=0.5, loc='right')
	i += 1
pyplot.show()

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

def preprocess(data):
  values = data.values
  encoder = LabelEncoder()
  values[:,3] = encoder.fit_transform(values[:,3])
  # ensure all data is float
  values = values.astype('float32')
  # normalize features
  scaler = MinMaxScaler(feature_range=(0, 1))
  scaled = scaler.fit_transform(values)
  # frame as supervised learning
  reframed = series_to_supervised(scaled, 1, 1)
  # drop columns we don't want to predict
  reframed.drop(reframed.columns[[3,5,6, 7]], axis=1, inplace=True)
  return reframed

# reframed.head()

# %%
from sklearn.model_selection import *

def _split(reframed):
  reframed_values = reframed.values
  n_train_hours = (int)(0.8*len(reframed_values))
  train = reframed_values[:n_train_hours, :]
  test = reframed_values[n_train_hours:, :]
  # split into input and outputs
  train_X, train_y = train[:, :-1], train[:, -1]
  test_X, test_y = test[:, :-1], test[:, -1]
  # reshape input to be 3D [samples, timesteps, features]
  train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
  test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
  print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
  return train_X, train_y, test_X, test_y

# %%
from sklearn.metrics import mean_squared_error, r2_score
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras import backend as K

# from keras.metrics import RootMeanSquaredError
#  metrics=[keras.metrics.RootMeanSquaredError(name='rmse')],
# design network

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true))) 
from keras import backend as K


def _model(data):
  reframed = preprocess(data)
  train_X, train_y, test_X, test_y = _split(reframed)
  model = Sequential()
  model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
  model.add(Dense(1))
  model.compile(loss=root_mean_squared_error, optimizer='adam')
  # fit network
  history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
  # plot history
  pyplot.plot(history.history['loss'], label='train')
  pyplot.plot(history.history['val_loss'], label='test')
  pyplot.legend()
  pyplot.show()
  return model,train_X, train_y, test_X, test_y

# %%
def predi(data):
  model,train_X, train_y, test_X, test_y = _model(data)
  # make a prediction
  yhat = model.predict(test_X)
  test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
  values = data.values
  encoder = LabelEncoder()
  values[:,3] = encoder.fit_transform(values[:,3])
  # ensure all data is float
  values = values.astype('float32')[:,:3]
  # normalize features
  scaler = MinMaxScaler(feature_range=(0, 1))
  scaled = scaler.fit(values)
  # invert scaling for forecast
  inv_yhat = np.concatenate((yhat, test_X[:, 1:]), axis=1)
  inv_yhat = scaler.inverse_transform(inv_yhat)
  inv_yhat = inv_yhat[:,0]
  # invert scaling for actual
  test_y = test_y.reshape((len(test_y), 1))
  inv_y = np.concatenate((test_y, test_X[:, 1:]), axis=1)
  inv_y = scaler.inverse_transform(inv_y)
  inv_y = inv_y[:,0]
  # calculate RMSE
  rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
  print('Test RMSE: %.3f' % rmse)

  print('R2 Score: %.4f' % r2_score(test_y,yhat))
  
  return model, inv_yhat, inv_y

# %%
model,train_X, train_y, test_X, test_y = _model(bui_1)

# %%
yhat = model.predict(test_X)

# %%
print('R2 Score: %.4f' % r2_score(test_y,yhat))

# %%
predi(bui_5)
# Out:
# (21119, 1, 3) (21119,) (5280, 1, 3) (5280,)
# Train on 21119 samples, validate on 5280 samples
# Epoch 1/50
#  - 2s - loss: 0.0557 - val_loss: 0.1142
# Epoch 2/50
#  - 1s - loss: 0.0472 - val_loss: 0.1009
# Epoch 3/50
#  - 1s - loss: 0.0434 - val_loss: 0.0875
# Epoch 4/50
#  - 1s - loss: 0.0401 - val_loss: 0.0735
# Epoch 5/50
#  - 1s - loss: 0.0376 - val_loss: 0.0614
# Epoch 6/50
#  - 1s - loss: 0.0359 - val_loss: 0.0535
# Epoch 7/50
#  - 1s - loss: 0.0350 - val_loss: 0.0507
# Epoch 8/50
#  - 1s - loss: 0.0346 - val_loss: 0.0499
# Epoch 9/50
#  - 1s - loss: 0.0344 - val_loss: 0.0497
# Epoch 10/50
#  - 1s - loss: 0.0344 - val_loss: 0.0497
# Epoch 11/50
#  - 1s - loss: 0.0344 - val_loss: 0.0498
# Epoch 12/50
#  - 1s - loss: 0.0344 - val_loss: 0.0499
# Epoch 13/50
#  - 1s - loss: 0.0344 - val_loss: 0.0500
# Epoch 14/50
#  - 1s - loss: 0.0343 - val_loss: 0.0501
# Epoch 15/50
#  - 1s - loss: 0.0343 - val_loss: 0.0501
# Epoch 16/50
#  - 1s - loss: 0.0343 - val_loss: 0.0502
# Epoch 17/50
# ...

# %%
models=[]
y_pred=np.array([])
y_test=np.array([])
for i in [bui_1,bui_2,bui_3,bui_4,bui_5]:
  m,yp,yt = predi(i)
  models.append(m)
  np.concatenate((y_pred,yp))
  np.concatenate((y_test,yt))
# Out:
# (21119, 1, 3) (21119,) (5280, 1, 3) (5280,)
# Train on 21119 samples, validate on 5280 samples
# Epoch 1/50
#  - 3s - loss: 0.0715 - val_loss: 0.1373
# Epoch 2/50
#  - 1s - loss: 0.0452 - val_loss: 0.1222
# Epoch 3/50
#  - 1s - loss: 0.0427 - val_loss: 0.1075
# Epoch 4/50
#  - 1s - loss: 0.0403 - val_loss: 0.0940
# Epoch 5/50
#  - 1s - loss: 0.0382 - val_loss: 0.0824
# Epoch 6/50
#  - 1s - loss: 0.0364 - val_loss: 0.0732
# Epoch 7/50
#  - 1s - loss: 0.0350 - val_loss: 0.0676
# Epoch 8/50
#  - 1s - loss: 0.0342 - val_loss: 0.0651
# Epoch 9/50
#  - 1s - loss: 0.0337 - val_loss: 0.0642
# Epoch 10/50
#  - 1s - loss: 0.0336 - val_loss: 0.0639
# Epoch 11/50
#  - 1s - loss: 0.0335 - val_loss: 0.0638
# Epoch 12/50
#  - 1s - loss: 0.0335 - val_loss: 0.0637
# Epoch 13/50
#  - 1s - loss: 0.0335 - val_loss: 0.0636
# Epoch 14/50
#  - 1s - loss: 0.0335 - val_loss: 0.0636
# Epoch 15/50
#  - 1s - loss: 0.0335 - val_loss: 0.0636
# Epoch 16/50
#  - 1s - loss: 0.0335 - val_loss: 0.0635
# Epoch 17/50
# ...
